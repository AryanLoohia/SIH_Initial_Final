# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# Example data (assuming you have a DataFrame with the extracted features)
df = pd.DataFrame(pd.read_excel('Features_Training.xlsx'))
df.head()
# Out:
#                                        Original Text  Length  \
# 0  tion, verify the last four digits of your debi...     157
# 1  s for transactions above a certain amount. You...     160
# 2  MFA) to safeguard your accounts. Your bank acc...     146
# 3  able app notifications for every transaction o...     145
# 4  ique hash value derived from the data it conta...     142
#
#                              Encrypted Data (Binary)  \
# 0  b'\x87?\x1b\x84\x82Az\x06\x12\xb7\x13\xbd\xb7u...
# 1  b'\xddmR\xcc\x0fFJr\xe7\x9b\xd9\xf2\xe3\xc6\xa...
# 2  b'_\xd1\xd9\xc9\xdc\x1d}\xa4\x8cd\xbf\xfb\xf1X...
# 3  b'\xf575/\x8b\xefA\xc7\xb1\xc6n\x11\xf6\xd2\x1...
# 4  b'\xae^\xcf\x06\x10\xf4x\xe8\xd8r\xad\xb4\x8e&...
#
#                                 Encrypted Data (Hex) Algorithm  length  \
# 0  873f1b8482417a0612b713bdb7758d78cb04f6c74bb4a7...       AES     176
# 1  dd6d52cc0f464a72e79bd9f2e3c6a9afa4a5204a31ef7f...       AES     192
# 2  5fd1d9c9dc1d7da48c64bffbf158849315265120126f1e...       AES     178
# 3  f537352f8bef41c7b1c66e11f6d21bf035d320beb49f38...       AES     176
# 4  ae5ecf0610f478e8d872adb48e26fc03816201a3d5d485...       ECC     142
#
#     entropy  freq_top_1_freq  freq_top_2_freq  freq_top_3_freq  ...  \
# 0  6.876879                4                3                3  ...
# 1  6.998872                4                3                3  ...
# 2  6.874500                4                4                4  ...
# 3  6.765460                5                4                4  ...
# 4  6.795771                3                3                3  ...
#
#    block_size  byte_distribution_mean  byte_distribution_std  \
# 0         8.0                1.375000               0.612372
# 1         8.0                1.381295               0.604488
# 2         NaN                1.369231               0.692137
# 3         8.0                1.454545               0.738549
# 4         NaN                1.203390               0.461378
#
#    repetition_count  avg_hamming_distance  bit_zeros_ratio  bit_ones_ratio  \
# 0               0.0             1037.5710         0.505682        0.494318
# 1               0.0              983.1739         0.475260        0.524740
# 2               0.0                0.0000         0.497191        0.502809
# 3               0.0             1061.2380         0.496449        0.503551
# 4               0.0                0.0000         0.511444        0.488556
#
#    padding_length                                                 iv  \
# 0               0  b'\x87?\x1b\x84\x82Az\x06\x12\xb7\x13\xbd\xb7u...
# 1               0  b'\xddmR\xcc\x0fFJr\xe7\x9b\xd9\xf2\xe3\xc6\xa...
# 2               0  b'_\xd1\xd9\xc9\xdc\x1d}\xa4\x8cd\xbf\xfb\xf1X...
# 3               0  b'\xf575/\x8b\xefA\xc7\xb1\xc6n\x11\xf6\xd2\x1...
# 4               0  b'\xae^\xcf\x06\x10\xf4x\xe8\xd8r\xad\xb4\x8e&...
#
#                        mode
# 0   CBC or other block mode
# 1   CBC or other block mode
# 2  Unknown or Stream Cipher
# 3   CBC or other block mode
# 4  Unknown or Stream Cipher
#
# [5 rows x 22 columns]

# %%
y_train = df['Algorithm']
df.drop(columns=['Original Text', 'Length', 'Encrypted Data (Binary)', 'Encrypted Data (Hex)', 'Algorithm', 'iv'], inplace=True)
X_train = df

# %%
y_train
# Out:
# 0      AES
# 1      AES
# 2      AES
# 3      AES
# 4      ECC
#       ...
# 645    ECC
# 646    AES
# 647    RSA
# 648    AES
# 649    RSA
# Name: Algorithm, Length: 650, dtype: object

# %%
X_train
# Out:
#      length   entropy  freq_top_1_freq  freq_top_2_freq  freq_top_3_freq  \
# 0       176  6.876879                4                3                3
# 1       192  6.998872                4                3                3
# 2       178  6.874500                4                4                4
# 3       176  6.765460                5                4                4
# 4       142  6.795771                3                3                3
# ..      ...       ...              ...              ...              ...
# 645     155  6.813064                4                3                3
# 646     160  6.771684                3                3                3
# 647     256  7.193973                4                4                4
# 648     176  6.752593                5                4                4
# 649     512  7.562785                8                6                6
#
#      freq_top_4_freq  freq_top_5_freq  block_size  byte_distribution_mean  \
# 0                  3                3         8.0                1.375000
# 1                  3                3         8.0                1.381295
# 2                  4                3         NaN                1.369231
# 3                  3                3         8.0                1.454545
# 4                  2                2         NaN                1.203390
# ..               ...              ...         ...                     ...
# 645                3                3         NaN                1.270492
# 646                3                3         8.0                1.344538
# 647                3                3         8.0                1.570552
# 648                3                3         8.0                1.454545
# 649                6                5         8.0                2.327273
#
#      byte_distribution_std  repetition_count  avg_hamming_distance  \
# 0                 0.612372          0.000000             1037.5710
# 1                 0.604488          0.000000              983.1739
# 2                 0.692137          0.000000                0.0000
# 3                 0.738549          0.000000             1061.2380
# 4                 0.461378          0.000000                0.0000
# ..                     ...               ...                   ...
# 645               0.573126          0.000000                0.0000
# 646               0.600238          0.006250             1040.3160
# 647               0.767190          0.003906             1012.2580
# 648               0.771389          0.000000              987.4286
# 649               1.318464          0.005859             1067.9050
#
#      bit_zeros_ratio  bit_ones_ratio  padding_length                      mode
# 0           0.505682        0.494318               0   CBC or other block mode
# 1           0.475260        0.524740               0   CBC or other block mode
# 2           0.497191        0.502809               0  Unknown or Stream Cipher
# 3           0.496449        0.503551               0   CBC or other block mode
# 4           0.511444        0.488556               0  Unknown or Stream Cipher
# ..               ...             ...             ...                       ...
# 645         0.504839        0.495161               0  Unknown or Stream Cipher
# 646         0.511719        0.488281               0   CBC or other block mode
# 647         0.500000        0.500000               0   CBC or other block mode
# 648         0.482955        0.517045               0   CBC or other block mode
# 649         0.491699        0.508301               0   CBC or other block mode
#
# [650 rows x 16 columns]

# %%
# Example data (assuming you have a DataFrame with the extracted features)
df = pd.DataFrame(pd.read_excel('Feature_Engineering_Testing1.xlsx'))
df.head()
# Out:
#                                        Original Text  Length  \
# 0  \nOnce upon a time, in a dense forest, there l...     136
# 1  .\nHe didn't want to harm his friend, but he a...     152
# 2  e home with me today?"\n\nThe monkey was thril...     145
# 3         was more cautious about whom he trusted.\n      41
# 4   day, a crocodile swam up to the bank of the r...     143
#
#                              Encrypted Data (Binary)  \
# 0  b'\xe81\x93\x8f\x85p\x90,\xe8\xaf\xe7\xb0/\x06...
# 1  b'&d\x9c\x955H7\x86\xb9#\xff6w$98\x90\x1c\x82\...
# 2  b'\xe2\x05,\x9d\xb7QH\xec\xd4\xd6\xc1\xe0@\xc4...
# 3  b'\x04\xa4\x1b\x82\xb4\xf5\xa9\x9c%\x0eL\x97/\...
# 4  b'\xe89AS\xf8\x9b{\x7f\xf0ft1\xf4\xf2\x0b(\xdb...
#
#                                 Encrypted Data (Hex) Algorithm  length  \
# 0  e831938f8570902ce8afe7b02f063e42be2891e0d3cd92...       ECC     136
# 1  26649c9535483786b923ff3677243938901c8298f9ddca...       ECC     152
# 2  e2052c9db75148ecd4d6c1e040c419051e25fa88d55ad5...       ECC     145
# 3  04a41b82b4f5a99c250e4c972ff2da0a0d0620ca030f1f...       ECC      41
# 4  e8394153f89b7b7ff0667431f4f20b28db01ec9751440d...       ECC     143
#
#     entropy  freq_top_1_freq  freq_top_2_freq  freq_top_3_freq  ...  \
# 0  6.550554                4                4                3  ...
# 1  6.726321                3                3                3  ...
# 2  6.607360                4                3                3  ...
# 3  5.259991                2                2                1  ...
# 4  6.735012                3                2                2  ...
#
#    block_size  byte_distribution_mean  byte_distribution_std  \
# 0         8.0                1.320388               0.641806
# 1         8.0                1.321739               0.583063
# 2         NaN                1.367925               0.603847
# 3         NaN                1.051282               0.220572
# 4         NaN                1.265487               0.461197
#
#    repetition_count  avg_hamming_distance  bit_zeros_ratio  bit_ones_ratio  \
# 0               0.0           1059.125000         0.530331        0.469669
# 1               0.0            951.333333         0.527961        0.472039
# 2               0.0              0.000000         0.495690        0.504310
# 3               0.0              0.000000         0.542683        0.457317
# 4               0.0              0.000000         0.474650        0.525350
#
#    padding_length                                                 iv  \
# 0               0  b'\xe81\x93\x8f\x85p\x90,\xe8\xaf\xe7\xb0/\x06>B'
# 1               0                 b'&d\x9c\x955H7\x86\xb9#\xff6w$98'
# 2               1  b'\xe2\x05,\x9d\xb7QH\xec\xd4\xd6\xc1\xe0@\xc4...
# 3               0  b'\x04\xa4\x1b\x82\xb4\xf5\xa9\x9c%\x0eL\x97/\...
# 4               0        b'\xe89AS\xf8\x9b{\x7f\xf0ft1\xf4\xf2\x0b('
#
#                        mode
# 0  Unknown or Stream Cipher
# 1  Unknown or Stream Cipher
# 2  Unknown or Stream Cipher
# 3  Unknown or Stream Cipher
# 4  Unknown or Stream Cipher
#
# [5 rows x 22 columns]

# %%
y_test = df['Algorithm']
df.drop(columns=['Original Text', 'Length', 'Encrypted Data (Binary)', 'Encrypted Data (Hex)', 'Algorithm', 'iv'], inplace=True)
X_test = df

# %%
y_test
# Out:
# 0     ECC
# 1     ECC
# 2     ECC
# 3     ECC
# 4     ECC
#      ...
# 79    ECC
# 80    ECC
# 81    ECC
# 82    ECC
# 83    ECC
# Name: Algorithm, Length: 84, dtype: object

# %%
X_test
# Out:
#     length   entropy  freq_top_1_freq  freq_top_2_freq  freq_top_3_freq  \
# 0      136  6.550554                4                4                3
# 1      152  6.726321                3                3                3
# 2      145  6.607360                4                3                3
# 3       41  5.259991                2                2                1
# 4      143  6.735012                3                2                2
# ..     ...       ...              ...              ...              ...
# 79     132  6.557541                3                3                3
# 80     142  6.649609                3                3                3
# 81     142  6.482184                4                3                3
# 82     145  6.783290                3                3                2
# 83     135  6.619227                3                3                3
#
#     freq_top_4_freq  freq_top_5_freq  block_size  byte_distribution_mean  \
# 0                 3                3         8.0                1.320388
# 1                 3                3         8.0                1.321739
# 2                 3                3         NaN                1.367925
# 3                 1                1         NaN                1.051282
# 4                 2                2         NaN                1.265487
# ..              ...              ...         ...                     ...
# 79                2                2         NaN                1.306931
# 80                3                2         NaN                1.314815
# 81                3                3         NaN                1.434343
# 82                2                2         NaN                1.239316
# 83                3                3         NaN                1.273585
#
#     byte_distribution_std  repetition_count  avg_hamming_distance  \
# 0                0.641806          0.000000           1059.125000
# 1                0.583063          0.000000            951.333333
# 2                0.603847          0.000000              0.000000
# 3                0.220572          0.000000              0.000000
# 4                0.461197          0.000000              0.000000
# ..                    ...               ...                   ...
# 79               0.521661          0.000000              0.000000
# 80               0.538313          0.014085              0.000000
# 81               0.698651          0.007042              0.000000
# 82               0.465008          0.000000              0.000000
# 83               0.541365          0.000000              0.000000
#
#     bit_zeros_ratio  bit_ones_ratio  padding_length                      mode
# 0          0.530331        0.469669               0  Unknown or Stream Cipher
# 1          0.527961        0.472039               0  Unknown or Stream Cipher
# 2          0.495690        0.504310               1  Unknown or Stream Cipher
# 3          0.542683        0.457317               0  Unknown or Stream Cipher
# 4          0.474650        0.525350               0  Unknown or Stream Cipher
# ..              ...             ...             ...                       ...
# 79         0.465909        0.534091               0  Unknown or Stream Cipher
# 80         0.513204        0.486796               0  Unknown or Stream Cipher
# 81         0.527289        0.472711               0  Unknown or Stream Cipher
# 82         0.508621        0.491379               0  Unknown or Stream Cipher
# 83         0.520370        0.479630               0  Unknown or Stream Cipher
#
# [84 rows x 16 columns]

# %%
y_train.isnull().sum()
# Out:
# 0

# %%
X_train.isnull().sum()
# Out:
# length                      0
# entropy                     0
# freq_top_1_freq             0
# freq_top_2_freq             0
# freq_top_3_freq             0
# freq_top_4_freq             0
# freq_top_5_freq             0
# block_size                264
# byte_distribution_mean      0
# byte_distribution_std       0
# repetition_count            0
# avg_hamming_distance        0
# bit_zeros_ratio             0
# bit_ones_ratio              0
# padding_length              0
# mode                        0
# dtype: int64

# %%
import numpy as np
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(missing_values=np.nan, strategy='median')
X_train['block_size'] = imputer.fit_transform(X_train[['block_size']])
X_train.isnull().sum()
# Out:
# length                    0
# entropy                   0
# freq_top_1_freq           0
# freq_top_2_freq           0
# freq_top_3_freq           0
# freq_top_4_freq           0
# freq_top_5_freq           0
# block_size                0
# byte_distribution_mean    0
# byte_distribution_std     0
# repetition_count          0
# avg_hamming_distance      0
# bit_zeros_ratio           0
# bit_ones_ratio            0
# padding_length            0
# mode                      0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
X_train['mode'] = label_encoder.fit_transform(X_train[['mode']])
X_train
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#      length   entropy  freq_top_1_freq  freq_top_2_freq  freq_top_3_freq  \
# 0       176  6.876879                4                3                3
# 1       192  6.998872                4                3                3
# 2       178  6.874500                4                4                4
# 3       176  6.765460                5                4                4
# 4       142  6.795771                3                3                3
# ..      ...       ...              ...              ...              ...
# 645     155  6.813064                4                3                3
# 646     160  6.771684                3                3                3
# 647     256  7.193973                4                4                4
# 648     176  6.752593                5                4                4
# 649     512  7.562785                8                6                6
#
#      freq_top_4_freq  freq_top_5_freq  block_size  byte_distribution_mean  \
# 0                  3                3         8.0                1.375000
# 1                  3                3         8.0                1.381295
# 2                  4                3         8.0                1.369231
# 3                  3                3         8.0                1.454545
# 4                  2                2         8.0                1.203390
# ..               ...              ...         ...                     ...
# 645                3                3         8.0                1.270492
# 646                3                3         8.0                1.344538
# 647                3                3         8.0                1.570552
# 648                3                3         8.0                1.454545
# 649                6                5         8.0                2.327273
#
#      byte_distribution_std  repetition_count  avg_hamming_distance  \
# 0                 0.612372          0.000000             1037.5710
# 1                 0.604488          0.000000              983.1739
# 2                 0.692137          0.000000                0.0000
# 3                 0.738549          0.000000             1061.2380
# 4                 0.461378          0.000000                0.0000
# ..                     ...               ...                   ...
# 645               0.573126          0.000000                0.0000
# 646               0.600238          0.006250             1040.3160
# 647               0.767190          0.003906             1012.2580
# 648               0.771389          0.000000              987.4286
# 649               1.318464          0.005859             1067.9050
#
#      bit_zeros_ratio  bit_ones_ratio  padding_length  mode
# 0           0.505682        0.494318               0     0
# 1           0.475260        0.524740               0     0
# 2           0.497191        0.502809               0     1
# 3           0.496449        0.503551               0     0
# 4           0.511444        0.488556               0     1
# ..               ...             ...             ...   ...
# 645         0.504839        0.495161               0     1
# 646         0.511719        0.488281               0     0
# 647         0.500000        0.500000               0     0
# 648         0.482955        0.517045               0     0
# 649         0.491699        0.508301               0     0
#
# [650 rows x 16 columns]

# %%
y_test.isnull().sum()
# Out:
# 0

# %%
X_test.isnull().sum()
# Out:
# length                     0
# entropy                    0
# freq_top_1_freq            0
# freq_top_2_freq            0
# freq_top_3_freq            0
# freq_top_4_freq            0
# freq_top_5_freq            0
# block_size                71
# byte_distribution_mean     0
# byte_distribution_std      0
# repetition_count           0
# avg_hamming_distance       0
# bit_zeros_ratio            0
# bit_ones_ratio             0
# padding_length             0
# mode                       0
# dtype: int64

# %%
import numpy as np
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(missing_values=np.nan, strategy='median')
X_test['block_size'] = imputer.fit_transform(X_test[['block_size']])
X_test.isnull().sum()
# Out:
# length                    0
# entropy                   0
# freq_top_1_freq           0
# freq_top_2_freq           0
# freq_top_3_freq           0
# freq_top_4_freq           0
# freq_top_5_freq           0
# block_size                0
# byte_distribution_mean    0
# byte_distribution_std     0
# repetition_count          0
# avg_hamming_distance      0
# bit_zeros_ratio           0
# bit_ones_ratio            0
# padding_length            0
# mode                      0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
X_test['mode'] = label_encoder.fit_transform(X_test[['mode']])
X_test
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#     length   entropy  freq_top_1_freq  freq_top_2_freq  freq_top_3_freq  \
# 0      136  6.550554                4                4                3
# 1      152  6.726321                3                3                3
# 2      145  6.607360                4                3                3
# 3       41  5.259991                2                2                1
# 4      143  6.735012                3                2                2
# ..     ...       ...              ...              ...              ...
# 79     132  6.557541                3                3                3
# 80     142  6.649609                3                3                3
# 81     142  6.482184                4                3                3
# 82     145  6.783290                3                3                2
# 83     135  6.619227                3                3                3
#
#     freq_top_4_freq  freq_top_5_freq  block_size  byte_distribution_mean  \
# 0                 3                3         8.0                1.320388
# 1                 3                3         8.0                1.321739
# 2                 3                3         8.0                1.367925
# 3                 1                1         8.0                1.051282
# 4                 2                2         8.0                1.265487
# ..              ...              ...         ...                     ...
# 79                2                2         8.0                1.306931
# 80                3                2         8.0                1.314815
# 81                3                3         8.0                1.434343
# 82                2                2         8.0                1.239316
# 83                3                3         8.0                1.273585
#
#     byte_distribution_std  repetition_count  avg_hamming_distance  \
# 0                0.641806          0.000000           1059.125000
# 1                0.583063          0.000000            951.333333
# 2                0.603847          0.000000              0.000000
# 3                0.220572          0.000000              0.000000
# 4                0.461197          0.000000              0.000000
# ..                    ...               ...                   ...
# 79               0.521661          0.000000              0.000000
# 80               0.538313          0.014085              0.000000
# 81               0.698651          0.007042              0.000000
# 82               0.465008          0.000000              0.000000
# 83               0.541365          0.000000              0.000000
#
#     bit_zeros_ratio  bit_ones_ratio  padding_length  mode
# 0          0.530331        0.469669               0     1
# 1          0.527961        0.472039               0     1
# 2          0.495690        0.504310               1     1
# 3          0.542683        0.457317               0     1
# 4          0.474650        0.525350               0     1
# ..              ...             ...             ...   ...
# 79         0.465909        0.534091               0     1
# 80         0.513204        0.486796               0     1
# 81         0.527289        0.472711               0     1
# 82         0.508621        0.491379               0     1
# 83         0.520370        0.479630               0     1
#
# [84 rows x 16 columns]

# %%
# Initialize Random Forest Classifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model
rf_model.fit(X_train, y_train)

# Make predictions
y_pred = rf_model.predict(X_test)
print(y_pred)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

# Print detailed classification report
print(classification_report(y_test, y_pred))
# Out:
# ['ECC' 'ECC' 'ECC' 'SHA' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC'
#  'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC'
#  'ECC' 'ECC' 'ECC' 'ECC' 'AES' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC'
#  'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC'
#  'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'SHA' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC'
#  'ECC' 'RSA' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC'
#  'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC' 'ECC']
# Accuracy: 95.24%
#               precision    recall  f1-score   support
#
#          AES       0.00      0.00      0.00         0
#          ECC       1.00      0.95      0.98        84
#          RSA       0.00      0.00      0.00         0
#          SHA       0.00      0.00      0.00         0
#
#     accuracy                           0.95        84
#    macro avg       0.25      0.24      0.24        84
# weighted avg       1.00      0.95      0.98        84
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
